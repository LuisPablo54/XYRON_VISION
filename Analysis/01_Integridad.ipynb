# %% [markdown]
# # Verificación de integridad de datos
#
# 07-09-2026
# - Luis Pablo López Iracheta

# %%
# Importación de librerías necesarias para la verifgicación de la integridad de los archivos
import hashlib
import os
# Librerias para ver una imagen jpg
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Seleccionamos una imagen de la carpeta de imágenes para verificar su integridad
image_train = os.path.join("..", "data_1", "train", "images", "0e538f39-1d30436c-c23_jpg.rf.3ce38b0e86b3cd83db06acc794de04f0.jpg")
# Verificamos si el archivo existe
if os.path.exists(image_train):
    # Abrimos el archivo y lo mostramos
    with open(image_train, "rb") as f:
        image_data = f.read()
        print(f"Imagen seleccionada: {image_train}")
        print(f"Tamaño de la imagen: {len(image_data)} bytes")
        # Imprimimos imagen para ver
        
        img = Image.open(image_train)
        plt.imshow(img)
        plt.title(f"Imagen: {image_train}")
        plt.axis("off")
        plt.show()
else:
    print(f"El archivo {image_train} no existe.")
# Out:
# Imagen seleccionada: ..\data_1\train\images\0e538f39-1d30436c-c23_jpg.rf.3ce38b0e86b3cd83db06acc794de04f0.jpg
# Tamaño de la imagen: 131866 bytes
